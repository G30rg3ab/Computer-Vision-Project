# %% [markdown]
# # Computer Vision Project

# %% [markdown]
# ### Setup

# %%
import os
import numpy as np
import cv2
import matplotlib.pyplot as plt
import pandas as pd
import albumentations as albu

# Custom modules
import segmentation as seg
import importlib

CLASSES = ['dog', 'cat', 'background']

# %% [markdown]
# ### Custom Dataset

# %%
DATA_DIR = 'Dataset/'

x_train_dir = os.path.join(DATA_DIR, 'TrainVal/color')
y_train_dir = os.path.join(DATA_DIR, 'TrainVal/label')

x_test_dir = os.path.join(DATA_DIR, 'Test/color')
y_test_dir = os.path.join(DATA_DIR, 'Test/label')

dataset = seg.CVDataset(x_train_dir, y_train_dir, CLASSES)

# %% [markdown]
# ### Custum visualisation function example

# %%
image, mask = dataset[300]
seg.visualiseData(image = image, mask = mask)

# %% [markdown]
# ### Preprocessing and data augmentations

# %%
augmented_dataset = seg.CVDataset(x_train_dir, y_train_dir, CLASSES, seg.get_training_augmentation())
image, mask = augmented_dataset[1200]
seg.visualiseData(image=image, mask = mask)
