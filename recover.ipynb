# %%
import nbformat

with open("train_prompt.ipynb") as f:
    notebook = nbformat.read(f, as_version=4)

with open("repaired_notebook.ipynb", "w") as f:
    nbformat.write(notebook, f)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File /opt/miniconda3/envs/cv/lib/python3.12/site-packages/nbformat/reader.py:19, in parse_json(s, **kwargs)
#      18 try:
# ---> 19     nb_dict = json.loads(s, **kwargs)
#      20 except ValueError as e:
#
# File /opt/miniconda3/envs/cv/lib/python3.12/json/__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#
# File /opt/miniconda3/envs/cv/lib/python3.12/json/decoder.py:341, in JSONDecoder.decode(self, s, _w)
#     340 if end != len(s):
# --> 341     raise JSONDecodeError("Extra data", s, end)
# ...
